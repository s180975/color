# %% [markdown]
# <a href="https://colab.research.google.com/github/s180975/color/blob/main/parvathipuram_ipynp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
world_map=folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
india_map=folium.Map(location=[20.5937,78.9629])
india_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
vizayanagram=folium.Map(location=[18.18201881044572, 83.38070292910946])
vizayanagram
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from branca.element import Figure
fig=Figure(width=550,height=350)
map1=folium.Map(location=[18.18201881044572, 83.38070292910946],zoom_start=12,min_zoom=8,max_zoom=20)
fig.add_child(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
way1=[[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8978, 81.6748], [17.0005, 81.8040],[16.9341, 81.9555],[17.0453, 82.1691],[17.2789, 82.4013],[17.3573, 82.5443],[17.6664, 82.6105],[17.5472, 82.8573],[17.6896, 83.0024],[17.6970, 83.1466],[17.7480, 83.2179],[17.6868, 83.2185],
      [17.7664, 83.2505],[18.1067, 83.3956],[18.1697, 83.3749],[18.2798, 83.3333],[18.6021, 83.3956],[18.4837, 83.3544],[18.5735, 83.3584],[18.7817, 83.4268]]
way2=[[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8978, 81.6748], [17.0005, 81.8040],[16.9341, 81.9555],[17.0453, 82.1691],[17.2789, 82.4013],[17.3573, 82.5443],[17.4324, 82.5226],[17.4952, 82.5524],[17.512883729776725, 82.579273376475],[17.6664, 82.6105],[17.8314, 82.9340],
      [17.8909, 83.1908],[18.1067, 83.3956],[18.1697, 83.3749],[18.2798, 83.3333],[18.6021, 83.3956],[18.4837, 83.3544],[18.5735, 83.3584],[18.7817, 83.4268]]
from branca.element import Figure
fig=Figure(width=550,height=350)
f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2")
map=folium.Map(location=[16.780001,80.849998],tiles='cartodbpositron')
line_1=folium.vector_layers.PolyLine(way1,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(way2,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f2)
f1.add_to(map)
f2.add_to(map)
folium.Marker(location=[17.6868, 83.2185],popup='Default popup Marker1',tooltip='Click here to see vizag beach',icon=folium.Icon(color="yellow",icon="VIZAG")).add_to(map)
folium.Marker(location=[17.7664, 83.2505],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see simhachalam temple</strong>',icon=folium.Icon(color='purple',icon="TEMPLE")).add_to(map)
folium.Marker(location=[18.1067, 83.3956],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see gantastambam</strong>',icon=folium.Icon(color='green',icon=" STAMBAM")).add_to(map)
folium.Marker(location=[16.7850, 80.8488],popup='Starting point',tooltip='Nuzvidu').add_to(map)
folium.Marker(location=[18.7817, 83.4268],popup='Destination',tooltip='Parvathipuram').add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: color argument of Icon should be one of: {'darkblue', 'gray', 'beige', 'darkred', 'purple', 'pink', 'lightgray', 'lightgreen', 'red', 'white', 'lightblue', 'green', 'darkgreen', 'darkpurple', 'black', 'orange', 'cadetblue', 'blue', 'lightred'}.
#   from ipykernel import kernelapp as app
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
fig5=Figure(height=550,width=750)
map5=folium.Map(location=[18.18201881044572, 83.38070292910946],tiles='cartodbpositron',zoom_start=14)
fig5.add_child(map5)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
